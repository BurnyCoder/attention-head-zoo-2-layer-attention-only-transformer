# %% [markdown]
# # L0H5 — Attends to just stuff like ,
#
# **Layer 0, Head 5**
#
# ## Types exhibited:
# - **Comma Attender** (full (100-90%))

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
import torch as t
from IPython.display import Markdown, display
from shared import (
    load_model, run_and_cache, get_attention_pattern,
    show_head_pattern, show_attention_tables, show_attention_to_position,
    show_self_attention_pcts, show_prev_token_pcts,
    show_attention_to_token, show_attention_from_token,
    show_few_prev_tokens_pcts, TEXT,
)

# %%
model = load_model()
str_tokens, logits, cache = run_and_cache(model)

# %% [markdown]
# ## Attention Pattern Visualization

# %%
show_head_pattern(str_tokens, cache, layer=0, head=5)

# %% [markdown]
# ## Attention Weight Tables
#
# Source to destination token pairs sorted by attention weight.

# %%
attention = get_attention_pattern(cache, layer=0, head=5)
show_attention_tables(str_tokens, attention, top_k=25)

# %% [markdown]
# ## Attention Strength by Type
#
# | Type | Activity Level | Percentage Range |
# |------|---------------|-----------------|
# | Comma Attender | full | 100-90% |
